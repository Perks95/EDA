# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\HP Demo\OneDrive - Stellenbosch University\Desktop\Python\Python\Titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Pclass'].unique()
df['Survived'].unique()
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
sns.countplot(x=df["Pclass"])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.replace(np.nan, '0', inplace= True)

df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age             object
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df[df['Pclass']==1].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 11           12         1       1
# 23           24         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 11      0    113783  26.5500  C103        S
# 23      0    113788  35.5000    A6        S

# %%
df[['Fare']].boxplot()
# Out:
# <Axes: >

# %%
df.corr()
# Out:
# C:\Users\HP Demo\AppData\Local\Temp\ipykernel_9848\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              PassengerId  Survived    Pclass     SibSp     Parch      Fare
# PassengerId     1.000000 -0.005007 -0.035144 -0.057527 -0.001652  0.012658
# Survived       -0.005007  1.000000 -0.338481 -0.035322  0.081629  0.257307
# Pclass         -0.035144 -0.338481  1.000000  0.083081  0.018443 -0.549500
# SibSp          -0.057527 -0.035322  0.083081  1.000000  0.414838  0.159651
# Parch          -0.001652  0.081629  0.018443  0.414838  1.000000  0.216225
# Fare            0.012658  0.257307 -0.549500  0.159651  0.216225  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\HP Demo\AppData\Local\Temp\ipykernel_9848\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
df= pd.read_csv(r"C:\Users\HP Demo\OneDrive - Stellenbosch University\Desktop\Python\Python\2. Cars Data1.csv")
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
df.tail()
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 427  $38,203          2.4        5.0       197.0      21.0         28.0
# 428  $40,083          2.3        5.0       242.0      20.0         26.0
# 429  $42,573          2.9        6.0       268.0      19.0         26.0
# 430  $24,641          1.9        4.0       170.0      22.0         29.0
# 431  $33,112          2.5        5.0       208.0      20.0         27.0
#
#      Weight  Wheelbase  Length
# 427  3450.0      105.0   186.0
# 428  3450.0      105.0   186.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      428 non-null    object
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    float64
#  10  MPG_City     428 non-null    float64
#  11  MPG_Highway  428 non-null    float64
#  12  Weight       428 non-null    float64
#  13  Wheelbase    428 non-null    float64
#  14  Length       428 non-null    float64
# dtypes: float64(8), object(7)
# memory usage: 50.8+ KB

# %%
df.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP            object
# Invoice         object
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
df.shape
# Out:
# (432, 15)

# %%
duplicate_rows_df= df[df.duplicated()]
print("numbers of duplicate rows:", duplicate_rows_df.shape)
# Out:
# numbers of duplicate rows: (3, 15)

# %%
df.count()
# Out:
# Make           428
# Model          428
# Type           428
# Origin         428
# DriveTrain     428
# MSRP           428
# Invoice        428
# EngineSize     428
# Cylinders      426
# Horsepower     428
# MPG_City       428
# MPG_Highway    428
# Weight         428
# Wheelbase      428
# Length         428
# dtype: int64

# %%
df= df.drop_duplicates()
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
df.count()
# Out:
# Make           428
# Model          428
# Type           428
# Origin         428
# DriveTrain     428
# MSRP           428
# Invoice        428
# EngineSize     428
# Cylinders      426
# Horsepower     428
# MPG_City       428
# MPG_Highway    428
# Weight         428
# Wheelbase      428
# Length         428
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Make           1
# Model          1
# Type           1
# Origin         1
# DriveTrain     1
# MSRP           1
# Invoice        1
# EngineSize     1
# Cylinders      3
# Horsepower     1
# MPG_City       1
# MPG_Highway    1
# Weight         1
# Wheelbase      1
# Length         1
# dtype: int64

# %%
df.dropna()
df.count()
# Out:
# Make           428
# Model          428
# Type           428
# Origin         428
# DriveTrain     428
# MSRP           428
# Invoice        428
# EngineSize     428
# Cylinders      426
# Horsepower     428
# MPG_City       428
# MPG_Highway    428
# Weight         428
# Wheelbase      428
# Length         428
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Make           1
# Model          1
# Type           1
# Origin         1
# DriveTrain     1
# MSRP           1
# Invoice        1
# EngineSize     1
# Cylinders      3
# Horsepower     1
# MPG_City       1
# MPG_Highway    1
# Weight         1
# Wheelbase      1
# Length         1
# dtype: int64

# %%
sns.boxplot(x=df["Length"])
# Out:
# <Axes: xlabel='Length'>

# %%
sns.boxplot(x=df["Cylinders"])
# Out:
# <Axes: xlabel='Cylinders'>

# %%
df.Make.value_counts().nlargest(40)
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Chrysler         15
# Volkswagen       15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Mazda            11
# Lexus            11
# Kia              11
# Pontiac          11
# Subaru           11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Saab              7
# Acura             7
# Porsche           7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %%
df.Make.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of cars by make")
plt.ylabel('Number of cars')
plt.xlabel('Make');

# %%
plt.figure(figsize=(10,5))
c=df.corr()
sns.heatmap(c,cmap='BrBG', annot= True)
c
# Out:
# C:\Users\HP Demo\AppData\Local\Temp\ipykernel_9848\330255646.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c=df.corr()
#              EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# EngineSize     1.000000   0.908002    0.787435 -0.709471    -0.717302
# Cylinders      0.908002   1.000000    0.810341 -0.684402    -0.676100
# Horsepower     0.787435   0.810341    1.000000 -0.676699    -0.647195
# MPG_City      -0.709471  -0.684402   -0.676699  1.000000     0.941021
# MPG_Highway   -0.717302  -0.676100   -0.647195  0.941021     1.000000
# Weight         0.807867   0.742209    0.630796 -0.737966    -0.790989
# Wheelbase      0.636517   0.546730    0.387398 -0.507284    -0.524661
# Length         0.637448   0.547783    0.381554 -0.501526    -0.466092
#
#                Weight  Wheelbase    Length
# ...

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['Horsepower'], df['Weight'])
ax.set_xlabel('HP')
ax.set_ylabel('Weight')
plt.show()

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\HP Demo\OneDrive - Stellenbosch University\Desktop\Python\Python\pokemon.csv")
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
data.corr()
# Out:
# C:\Users\HP Demo\AppData\Local\Temp\ipykernel_9848\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                    #        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# #           1.000000  0.097712  0.102664  0.094691  0.089199  0.085596
# HP          0.097712  1.000000  0.422386  0.239622  0.362380  0.378718
# Attack      0.102664  0.422386  1.000000  0.438687  0.396362  0.263990
# Defense     0.094691  0.239622  0.438687  1.000000  0.223549  0.510747
# Sp. Atk     0.089199  0.362380  0.396362  0.223549  1.000000  0.506121
# Sp. Def     0.085596  0.378718  0.263990  0.510747  0.506121  1.000000
# Speed       0.012181  0.175952  0.381240  0.015227  0.473018  0.259133
# Generation  0.983428  0.058683  0.051451  0.042419  0.036437  0.028486
# ...

# %%
fig, ax = plt.subplots(figsize=(18,18))
sns.heatmap(data.corr(), annot =True, linewidths=.5, fmt=".1f", ax=ax)
plt.show()
# Out:
# C:\Users\HP Demo\AppData\Local\Temp\ipykernel_9848\1230986324.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot =True, linewidths=.5, fmt=".1f", ax=ax)

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
data.Speed.plot(kind ='line', color= 'g', label="Speed", linewidth =1, alpha =0.5, grid =True, linestyle=":")
data.Defense.plot(color = 'r',label = 'Defense',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper right')     # legend = puts label into plot
plt.xlabel('x axis')              # label = name of label
plt.ylabel('y axis')
plt.title('Line Plot')            # title = title of plot
plt.show()

# %%
data.plot(kind ='scatter', x= "Attack", y ="Defense", label="Speed",alpha =0.5, color = 'red')
plt.xlabel("Attack")
plt.ylabel("Defense")
plt.title("Attack Defense Scatter Plot")
plt.show()

# %%
data.Speed.plot(kind="hist", bins= 50, figsize=(12,12))
plt.show()

# %%
dictionary = {'spain' : 'madrid','usa' : 'vegas'}
print(dictionary.keys())
print(dictionary.values())
# Out:
# dict_keys(['spain', 'usa'])
# dict_values(['madrid', 'vegas'])

# %%
dictionary['spain'] = "barcelona"    # update existing entry
print(dictionary)
dictionary['france'] = "paris"       # Add new entry
print(dictionary)
del dictionary['spain']  
print(dictionary)
print('france' in dictionary)        # check include or not
dictionary.clear()                   # remove all entries in dict
print(dictionary)
# Out:
# {'spain': 'barcelona', 'usa': 'vegas'}
# {'spain': 'barcelona', 'usa': 'vegas', 'france': 'paris'}
# {'usa': 'vegas', 'france': 'paris'}
# True
# {}

# %%
data = pd.read_csv(r"C:\Users\HP Demo\OneDrive - Stellenbosch University\Desktop\Python\Python\pokemon.csv")

# %%
series = data['Defense']  
print(type(series))
data_frame = data[['Defense']]  # data[['Defense']] = data frame
print(type(data_frame))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
print(3>2)
print(3!=2)
print(True and False)
print(True or False)
# Out:
# True
# True
# False
# True

# %%
x = data['Defense']>200

data[x]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 230  231       Shuckle    Bug    Rock  20      10      230       10      230
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 230      5           2      False
# 333     50           3      False

# %%
data[np.logical_and(data['Defense']>200, data['Attack']>100 )]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 333     50           3      False

# %%
data[(data['Defense']>200) & (data['Attack']>100)]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 333     50           3      False

# %%
i = 0
while i != 5 :
    print('i is: ',i)
    i +=1
print(i,' is equal to 5')
# Out:
# i is:  0
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# 5  is equal to 5

# %%
lis = [1,2,3,4,5]
for i in lis:
    print('i is: ',i)
print('')

# Enumerate index and value of list
# index : value = 0:1, 1:2, 2:3, 3:4, 4:5
for index, value in enumerate(lis):
    print(index," : ",value)
print('')   

# For dictionaries
# We can use for loop to achive key and value of dictionary. We learnt key and value at dictionary part.
dictionary = {'spain':'madrid','france':'paris'}
for key,value in dictionary.items():
    print(key," : ",value)
print('')

# For pandas we can achieve index and value
for index,value in data[['Attack']][0:1].iterrows():
    print(index," : ",value)
# Out:
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# i is:  5
#
# 0  :  1
# 1  :  2
# 2  :  3
# 3  :  4
# 4  :  5
#
# spain  :  madrid
# france  :  paris
#
# 0  :  Attack    49
# Name: 0, dtype: int64

# %%
def tuple_ex():
    """return defined t tuple"""
    t =(1,2,3)
    return t
a,b,c = tuple_ex()
print(a,b,c)
# Out:
# 1 2 3

# %%
x = 2
def f():
    x = 3
    return x
print(x)      # x = 2 global scope
print(f())    # x = 3 local scope
# Out:
# 2
# 3

# %%
x = 5
def f():
    y = 2*x        # there is no local scope x
    return y
print(f())
# Out:
# 10

# %%
import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
# ...

# %%
def square ():
    def add():
        x = 2
        y = 3
        z = x + y
        return z
    return add()**2
print(square())
# Out:
# 25

# %%
def f(a, b = 1, c = 2):
    y = a + b + c
    return y
print(f(5))
# what if we want to change default arguments
print(f(5,4,3))
# Out:
# 8
# 12

# %%
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data.tail()
# Out:
#        #            Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  796         Diancie     Rock  Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock  Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic  Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic   Dark  80     160       60      170
# 799  800       Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
data.shape
# Out:
# (800, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
data["Type 1"].value_counts(dropna=False)
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data["Type 1"].value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Type 1")
plt.ylabel('level')
plt.xlabel('Type');

# %%
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
data.boxplot(column='Attack', by= 'Legendary')
# Out:
# <Axes: title={'center': 'Attack'}, xlabel='Legendary'>

# %%
def f(*args):
    for i in args:
        print(i)
f(1)
print("")
f(1,2,3,4)
# flexible arguments **kwargs that is dictionary
def f(**kwargs):
    """ print key and value of dictionary"""
    for key, value in kwargs.items():               # If you do not understand this part turn for loop part and look at dictionary in for loop
        print(key, " ", value)
f(country = 'spain', capital = 'madrid', population = 123456)
# Out:
# 1
#
# 1
# 2
# 3
# 4
# country   spain
# capital   madrid
# population   123456

# %%
square = lambda x: x**2

print(square(4))
tot = lambda x,y,z: x+y+z

print(tot(1,2,3))
# Out:
# 16
# 6

# %%
name = "ronaldo"
it = iter(name)
print(next(it))    # print next iteration
print(*it)
# Out:
# r
# o n a l d o

# %%
name = "Pereka"
it =iter(name)
print(next(it))
# Out:
# P

# %%
list1= [1,2,3,4]
list2= [5,6,7,8]
z = zip(list1, list2)
print(list(z))
# Out:
# [(1, 5), (2, 6), (3, 7), (4, 8)]

# %%
num1 = [1,2,3]
num2 = [i + 1 for i in num1 ]
print(num2)
# Out:
# [2, 3, 4]

# %%
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data1=data.loc[:,["Attack", 'Defense', "Speed"]]
data1.plot(kind="line")
plt.show()

# %%
data1.plot(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
sns.scatterplot(data=data1, x ="Attack", y= "Defense")
# Out:
# <Axes: xlabel='Attack', ylabel='Defense'>

# %%
sns.histplot(data=data1, x="Defense", bins=50, kde= True)
# Out:
# <Axes: xlabel='Defense', ylabel='Count'>

# %%
fig , ax= plt.subplots(nrows=2,ncols=1)
sns.histplot(data=data1, x="Defense", bins=50, kde= True,ax = ax[0])
sns.histplot(data=data1, x="Defense", bins=50, kde= True,ax = ax[1],cumulative = True)
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\HP Demo\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python310\\site-packages\\matplotlib\\pyplot.py'>

# %%
time_list = ["1992-03-08","1992-04-12"]
print(type(time_list[1])) # As you can see date is string
# however we want it to be datetime object
datetime_object = pd.to_datetime(time_list)
print(type(datetime_object))
# Out:
# <class 'str'>
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data.describe(include=["object"])
# Out:
#              Name Type 1  Type 2
# count         799    800     414
# unique        799     18      18
# top     Bulbasaur  Water  Flying
# freq            1    112      97

# %%
data.rename(columns={"Type 1": "Pokemon Type 1", 'Type 2': "Pokemon Type 2"},inplace = True)
data.head()
# Out:
#    #           Name Pokemon Type 1 Pokemon Type 2  HP  Attack  Defense  \
# 0  1      Bulbasaur          Grass         Poison  45      49       49
# 1  2        Ivysaur          Grass         Poison  60      62       63
# 2  3       Venusaur          Grass         Poison  80      82       83
# 3  4  Mega Venusaur          Grass         Poison  80     100      123
# 4  5     Charmander           Fire            NaN  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df_cols = ['new_carat', 'new_cut', 'new_color', 'new_clarity', 'new_depth', 'new_table', 'new_price', 'new_x', 'new_y', 'new_z']
#df.columns = df_cols

# %% [markdown]
# Write a pandas program to remove the second column of the diamonds Dataframe.

# %%
df.drop("",axis=1, inplace = True)

# %% [markdown]
#  Write a Pandas program to remove multiple columns at once of the diamonds Dataframe

# %%
#df= df.drop(['new_carat', 'new_cut', 'new_color', 'new_clarity', 'new_depth', 'new_table', 'new_price', 'new_x', 'new_y', 'new_z'], axis=1, inplace= True)

# %% [markdown]
# Remove multiple rows at once from diamonds dataframe

# %%
#df.drop([2,4,5],axis=0, inplace = True)

# %% [markdown]
# Sort the 'cut' Series in ascending order of diamonds Dataframe

# %%
df.cut.sort_values(ascending=True)

# %% [markdown]
# Write a pandas program to sort the 'price' Series in descending order (returns a Series) of diamonds Dataframe

# %%
df.price.sort_values(ascending= False)

# %% [markdown]
# Write a pandas program to sort the entire diamonds DataFrame by the ‘carat’ Series in ascending and descending order.

# %%
df.sort_values("carat", ascending=False)

# %% [markdown]
# Write a pandas program to filter the DataFrame rows to only show carat weight at least 0.3.

# %%
data[data.HP>=0.3]
# Out:
#        #            Name Pokemon Type 1 Pokemon Type 2  HP  Attack  Defense  \
# 0      1       Bulbasaur          Grass         Poison  45      49       49
# 1      2         Ivysaur          Grass         Poison  60      62       63
# 2      3        Venusaur          Grass         Poison  80      82       83
# 3      4   Mega Venusaur          Grass         Poison  80     100      123
# 4      5      Charmander           Fire            NaN  39      52       43
# ..   ...             ...            ...            ...  ..     ...      ...
# 795  796         Diancie           Rock          Fairy  50     100      150
# 796  797    Mega Diancie           Rock          Fairy  50     160      110
# 797  798  Hoopa Confined        Psychic          Ghost  80     110       60
# 798  799   Hoopa Unbound        Psychic           Dark  80     160       60
# 799  800       Volcanion           Fire          Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Write a pandas program to convert a python list to pandas series.

# %%
l = [1, 3, 5, 7, 9, 11]
numbers = pd.Series(l)
numbers
# Out:
# 0     1
# 1     3
# 2     5
# 3     7
# 4     9
# 5    11
# dtype: int64

# %% [markdown]
# Write a Pandas program to find the details of the diamonds where length>5, width>5 and depth>5.

# %%
data[(data["length"]>5) & (data["width"]>5) & (data["depth"]>5)]

# %% [markdown]
# Write a Pandas program to find the diamonds that are either Premium or Ideal.

# %%
data[(data.cut == 'Premium') | (data.cut == 'Ideal')]

# %% [markdown]
# Write a pandas program to find the diamonds that are with a Fair or Good or Premium.

# %%
data[(data.cut == 'Fair') or (data.cut == 'Good') or (data.cut == 'Premium')] #or 
data[data.cut.isin(['Fair', 'Good', 'Premium'])]

# %% [markdown]
#  Write a pandas program to display all column labels of diamonds DataFrame.

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Pokemon Type 1', 'Pokemon Type 2', 'HP', 'Attack',
#        'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
#  Write a Pandas program to read only a subset of 3 rows from diamonds DataFrame.

# %%
result = pd.read_csv('http://bit.ly/uforeports', nrows=3)

# %% [markdown]
# Write a Pandas program to iterate through diamonds DataFrame.

# %%
for i in data:
    print(index, row.carat, row.cut, row.color, row.price)

# %% [markdown]
#  Write a Pandas program to drop all non-numeric columns from diamonds DataFrame.

# %%
data=data.select_dtypestype(include= 'number')
# Out:
#       # Name Pokemon Type 1 Pokemon Type 2  HP  Attack  Defense  Sp. Atk  \
# 0   NaN  NaN            NaN            NaN NaN     NaN      NaN      NaN
# 1   NaN  NaN            NaN            NaN NaN     NaN      NaN      NaN
# 2   NaN  NaN            NaN            NaN NaN     NaN      NaN      NaN
# 3   NaN  NaN            NaN            NaN NaN     NaN      NaN      NaN
# 4   NaN  NaN            NaN            NaN NaN     NaN      NaN      NaN
# ..   ..  ...            ...            ...  ..     ...      ...      ...
# 795 NaN  NaN            NaN            NaN NaN     NaN      NaN      NaN
# 796 NaN  NaN            NaN            NaN NaN     NaN      NaN      NaN
# 797 NaN  NaN            NaN            NaN NaN     NaN      NaN      NaN
# 798 NaN  NaN            NaN            NaN NaN     NaN      NaN      NaN
# 799 NaN  NaN            NaN            NaN NaN     NaN      NaN      NaN
#
#      Sp. Def  Speed  Generation Legendary
# 0        NaN    NaN         NaN       NaN
# ...

# %% [markdown]
#  Write a Pandas program to drop all non-numeric columns from diamonds DataFrame.

# %%
data_numerical = data.drop(data.select_dtype(include= "number"))

# %% [markdown]
#  Write a Pandas program to pass a list of data types to only describe certain types of diamonds DataFrame.

# %%
data.describe( include=["object", "float64"])
# Out:
#              Name Pokemon Type 1 Pokemon Type 2
# count         799            800            414
# unique        799             18             18
# top     Bulbasaur          Water         Flying
# freq            1            112             97

# %% [markdown]
# Write a Pandas program to calculate the mean of each numeric column of diamonds DataFrame

# %%
data.mean()
# Out:
# C:\Users\HP Demo\AppData\Local\Temp\ipykernel_9848\531903386.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# #             400.50000
# HP             69.25875
# Attack         79.00125
# Defense        73.84250
# Sp. Atk        72.82000
# Sp. Def        71.90250
# Speed          68.27750
# Generation      3.32375
# Legendary       0.08125
# dtype: float64

# %% [markdown]
# Write a Pandas program to calculate the mean of each row of diamonds DataFram

# %%
data.mean(axis=1).head()
# Out:
# C:\Users\HP Demo\AppData\Local\Temp\ipykernel_9848\2221169960.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean(axis=1).head()
# 0    35.555556
# 1    45.333333
# 2    58.777778
# 3    70.000000
# 4    35.000000
# dtype: float64

# %% [markdown]
# Write a Pandas program to calculate the mean of price for each cut of diamonds DataFrame.

# %%
data.groupby("Price").mean()

# %% [markdown]
# Write a Pandas program to calculate count, minimum, maximum price for each cut of diamonds DataFrame.

# %%
data.groupby('cut').price.agg(['count', 'min', 'max']))
